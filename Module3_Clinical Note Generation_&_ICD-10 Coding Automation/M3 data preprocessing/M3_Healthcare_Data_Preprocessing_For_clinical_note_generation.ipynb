# %% [markdown]
# # Healthcare Data Preprocessing and Integration
#
# This notebook demonstrates the preprocessing and integration of healthcare data from various sources, including patient records, ICD-10 codes, and medical images, to prepare a unified dataset for downstream tasks like clinical note generation.

# %% [markdown]
# # Module 3: Healthcare Data Preprocessing for Clinical Note Generation
# In this step, we will:
# 1. Load the healthcare dataset.
# 2. Drop irrelevant administrative columns.
# 3. Convert numeric and date columns into descriptive text.
# 4. Prepare a readable dataset for further text-based AI processing.

# %%
import pandas as pd

# Path to your dataset (use the one from Module 1 or the initial healthcare dataset)
healthcare_path = "/content/healthcare_dataset.csv"
df = pd.read_csv(healthcare_path)

print("✅ Healthcare dataset loaded successfully!")
print("Shape:", df.shape)
display(df.head())
# Out:
# ✅ Healthcare dataset loaded successfully!
# Shape: (55500, 15)
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ## Step 1: Select Relevant Columns
# We'll keep only the columns useful for clinical summarization and note generation.
# These include:
# - Patient identifiers (Name, Age, Gender)
# - Medical details (Blood Type, Medical Condition, Medication, Test Results)
# - Context (Doctor, Hospital, Admission Type)
# - Timeline (Date of Admission, Discharge Date)

# %%
# Keep only relevant columns
keep_cols = [
    "Name", "Age", "Gender", "Blood Type", "Medical Condition",
    "Date of Admission", "Discharge Date", "Doctor", "Hospital",
    "Admission Type", "Medication", "Test Results"
]

df = df[keep_cols].copy()
print("✅ Selected columns:")
print(df.columns.tolist())
display(df.head(3))
# Out:
# ✅ Selected columns:
# ['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Date of Admission', 'Discharge Date', 'Doctor', 'Hospital', 'Admission Type', 'Medication', 'Test Results']
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
#
#   Discharge Date            Doctor         Hospital Admission Type  \
# 0     2024-02-02     Matthew Smith  Sons and Miller         Urgent
# 1     2019-08-26   Samantha Davies          Kim Inc      Emergency
# 2     2022-10-07  Tiffany Mitchell         Cook PLC      Emergency
#
#     Medication  Test Results
# 0  Paracetamol        Normal
# 1    Ibuprofen  Inconclusive
# 2      Aspirin        Normal

# %% [markdown]
# ## Step 2: Convert Dates, Numbers, and Categories into Text
# - Dates → “January 31, 2024”
# - Age → “30-year-old”
# - Blood Type → embedded in the description
# - Admission Type → standardized text (urgent, routine, emergency, etc.)

# %%
from datetime import datetime
import pandas as pd
import uuid

def format_date(date_str):
    """Convert date string (DD-MM-YYYY or similar) into readable Month DD, YYYY"""
    try:
        return datetime.strptime(str(date_str), "%d-%m-%Y").strftime("%B %d, %Y")
    except:
        try:
            return datetime.strptime(str(date_str), "%Y-%m-%d").strftime("%B %d, %Y")
        except:
            return str(date_str)

df["Date of Admission"] = df["Date of Admission"].apply(format_date)
df["Discharge Date"] = df["Discharge Date"].apply(format_date)

# Age to text - only apply if the column is not already in the desired text format
if not df['Age'].astype(str).str.contains('-year-old').any():
    df["Age"] = df["Age"].apply(lambda x: f"{int(x)}-year-old" if pd.notnull(x) else "age not specified")


# Standardize Admission Type text
df["Admission Type"] = df["Admission Type"].str.capitalize().replace({
    "Urgent": "urgent admission",
    "Emergency": "emergency admission",
    "Routine": "routine admission",
    "Elective": "elective admission"
})

# Explicitly drop the 'Age_Text' column if it exists
if 'Age_Text' in df.columns:
    df = df.drop(columns=['Age_Text'])

# Add a unique patient ID
if 'patient_id' not in df.columns:
    df.insert(0, 'patient_id', range(1001, 1001 + len(df)))


print("✅ Dates, age, and admission type converted to text.")
display(df.head(3))
# Out:
# ✅ Dates, age, and admission type converted to text.
#    patient_id           Name          Age  Gender Blood Type  \
# 0           1  Bobby Jackson  30-year-old    Male          B
# 1           2   Leslie Terry  62-year-old    Male         A+
# 2           3    Danny Smith  76-year-old  Female          A
#
#   Medical Condition   Date of Admission     Discharge Date            Doctor  \
# 0            Cancer    January 31, 2024  February 02, 2024     Matthew Smith
# 1           Obesity     August 20, 2019    August 26, 2019   Samantha Davies
# 2           Obesity  September 22, 2022   October 07, 2022  Tiffany Mitchell
#
#           Hospital       Admission Type   Medication  Test Results
# 0  Sons And Miller     Urgent admission  Paracetamol        Normal
# 1          Kim Inc  Emergency admission    Ibuprofen  Inconclusive
# 2         Cook Plc  Emergency admission      Aspirin        Normal

# %% [markdown]
# ## Step 3: Standardize Text Columns
# Make textual columns uniform (capitalize names, remove special symbols, etc.)

# %%
# Basic cleaning
for col in ["Name", "Gender", "Blood Type", "Medical Condition", "Doctor", "Hospital", "Medication", "Test Results"]:
    df[col] = df[col].astype(str).str.strip().str.replace(r"[_-]+", " ", regex=True).str.title()

print("✅ Cleaned textual columns.")
display(df.head(5))
# Out:
# ✅ Cleaned textual columns.
#    patient_id           Name          Age  Gender Blood Type  \
# 0           1  Bobby Jackson  30-year-old    Male          B
# 1           2   Leslie Terry  62-year-old    Male         A+
# 2           3    Danny Smith  76-year-old  Female          A
# 3           4   Andrew Watts  28-year-old  Female         O+
# 4           5  Adrienne Bell  43-year-old  Female        Ab+
#
#   Medical Condition   Date of Admission     Discharge Date            Doctor  \
# 0            Cancer    January 31, 2024  February 02, 2024     Matthew Smith
# 1           Obesity     August 20, 2019    August 26, 2019   Samantha Davies
# 2           Obesity  September 22, 2022   October 07, 2022  Tiffany Mitchell
# 3          Diabetes   November 18, 2020  December 18, 2020       Kevin Wells
# 4            Cancer  September 19, 2022   October 09, 2022    Kathleen Hanna
#
#                      Hospital       Admission Type   Medication  Test Results
# 0             Sons And Miller     Urgent admission  Paracetamol        Normal
# 1                     Kim Inc  Emergency admission    Ibuprofen  Inconclusive
# 2                    Cook Plc  Emergency admission      Aspirin        Normal
# 3  Hernandez Rogers And Vang,   Elective admission    Ibuprofen      Abnormal
# 4                 White White     Urgent admission   Penicillin      Abnormal

# %%
import pandas as pd

# Load your preprocessed healthcare dataset
# df = pd.read_csv("/content/cleaned_data/healthcare_preprocessed.csv") # Removed this line

# Optional: If patient_id not present, create it
if 'patient_id' not in df.columns:
    df.insert(0, 'patient_id', range(1001, 1001 + len(df)))

# Create a clean, readable textual input for the model
df['summary_input'] = (
    "Patient " + df['Name'] + ", a " + df['Age'] + " " + df['Gender'].str.lower() +
    " with blood type " + df['Blood Type'] +
    ", was admitted on " + df['Date of Admission'] +
    " for " + df['Medical Condition'] + ". " +
    "The admission type was " + df['Admission Type'] +
    " under Dr. " + df['Doctor'] + " at " + df['Hospital'] + ". " +
    "Medication prescribed: " + df['Medication'] +
    ". Test Results: " + df['Test Results'] + "."
)

# Display first few examples
display(df[['patient_id', 'summary_input']].head())
# Out:
#    patient_id                                      summary_input
# 0           1  Patient Bobby Jackson, a 30-year-old male with...
# 1           2  Patient Leslie Terry, a 62-year-old male with ...
# 2           3  Patient Danny Smith, a 76-year-old female with...
# 3           4  Patient Andrew Watts, a 28-year-old female wit...
# 4           5  Patient Adrienne Bell, a 43-year-old female wi...

# %%
import pandas as pd

# Load your preprocessed healthcare data
df = pd.read_csv("/content/healthcare_dataset_preprocessed.csv")

# Create new patient IDs in proper hospital-like format
df.insert(0, 'patient_id', ['P' + str(1000 + i) for i in range(len(df))])

# Create condition keywords for later ICD mapping
df['condition_keywords'] = df['Medical Condition'].str.lower().str.strip()

# Create improved textual summaries for GenAI input
df['summary_input'] = (
    "Patient " + df['Name'] + ", a " + df['Age'] + " " + df['Gender'].str.lower() +
    " with blood type " + df['Blood Type'] +
    ", was admitted on " + df['Date of Admission'] +
    " for " + df['Medical Condition'] + ". " +
    "The admission was " + df['Admission Type'].str.lower() +
    " under Dr. " + df['Doctor'] + " at " + df['Hospital'] + ". " +
    "Medication prescribed includes " + df['Medication'] +
    ". Test results were " + df['Test Results'] + "."
)

# Display a few rows
df[['patient_id', 'summary_input', 'condition_keywords']].head()
# Out:
#   patient_id                                      summary_input  \
# 0      P1000  Patient Bobby Jackson, a 30-year-old male with...
# 1      P1001  Patient Leslie Terry, a 62-year-old male with ...
# 2      P1002  Patient Danny Smith, a 76-year-old female with...
# 3      P1003  Patient Andrew Watts, a 28-year-old female wit...
# 4      P1004  Patient Adrienne Bell, a 43-year-old female wi...
#
#   condition_keywords
# 0             cancer
# 1            obesity
# 2            obesity
# 3           diabetes
# 4             cancer

# %%
df.to_csv("/content/cleaned_data/healthcare_textual_ready.csv", index=False)
print("✅ Healthcare textual dataset saved successfully!")
# Out:
# ✅ Healthcare textual dataset saved successfully!

# %%
from google.colab import files

# Assuming the final dataset is saved at this path
files.download('/content/cleaned_data/healthcare_textual_ready.csv')

# %% [markdown]
# ### Step 4  — Integrate All Processed Data Sources
#
# In this step, we’ll merge:
# - Preprocessed Healthcare Dataset (EHR)
# - ICD-10 Dataset (code + description)
# - Enhanced Image Index (X-ray + Prescription from Module 2)
#
# Goal:
# Create one unified dataset (`merged_patient_dataset.csv`) that contains all relevant info for each patient record — ready for text generation using an LLM.

# %%
import pandas as pd
import numpy as np
import os

# Define paths to all datasets
healthcare_path = "/content/cleaned_data/healthcare_textual_ready.csv"       # from your preprocessed step
icd_path = "/content/cleaned_icdcodeset.csv"
enhanced_index_path = "/content/enhanced_image_index.csv"

# Load datasets
df_health = pd.read_csv(healthcare_path)
df_icd = pd.read_csv(icd_path)
df_imgs = pd.read_csv(enhanced_index_path)

print("✅ Datasets Loaded Successfully!")
print("Healthcare:", df_health.shape)
print("ICD Codes:", df_icd.shape)
print("Enhanced Image Index:", df_imgs.shape)

display(df_health.head(2))
display(df_icd.head(2))
display(df_imgs.head(2))
# Out:
# ✅ Datasets Loaded Successfully!
# Healthcare: (55500, 15)
# ICD Codes: (73639, 2)
# Enhanced Image Index: (5680, 4)
#   patient_id           Name          Age Gender Blood Type Medical Condition  \
# 0      P1000  Bobby Jackson  30-year-old   Male          B            Cancer
# 1      P1001   Leslie Terry  62-year-old   Male         A+           Obesity
#
#   Date of Admission     Discharge Date           Doctor         Hospital  \
# 0  January 31, 2024  February 02, 2024    Matthew Smith  Sons And Miller
# 1   August 20, 2019    August 26, 2019  Samantha Davies          Kim Inc
#
#         Admission Type   Medication  Test Results condition_keywords  \
# 0     Urgent admission  Paracetamol        Normal             cancer
# 1  Emergency admission    Ibuprofen  Inconclusive            obesity
#
#                                        summary_input
# 0  Patient Bobby Jackson, a 30-year-old male with...
# 1  Patient Leslie Terry, a 62-year-old male with ...
#   ICDCode                                        Description
# 0    A000     Cholera due to Vibrio cholerae 01, biovar c...
# 1    A001     Cholera due to Vibrio cholerae 01, biovar e...
#                                        original_path  \
# 0  /content/xray_data/XraysData/valid/adenocarcin...
# 1  /content/xray_data/XraysData/valid/adenocarcin...
#
#                                        enhanced_path       psnr      ssim
# 0  /content/enhanced_images/xray_enhanced/000115.png  21.593953  0.746678
# 1  /content/enhanced_images/xray_enhanced/000117 ...  23.827213  0.705685

# %%
# !unzip /content/prescription_enhanced.zip -d /content/
# !unzip /content/xray_enhanced.zip -d /content/
# Out:
# Archive:  /content/prescription_enhanced.zip
# replace /content/prescription_enhanced/0.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/prescription_enhanced/0.png
#   inflating: /content/prescription_enhanced/1.png
#   inflating: /content/prescription_enhanced/10.png
#   inflating: /content/prescription_enhanced/100.png
#   inflating: /content/prescription_enhanced/1000.png
#   inflating: /content/prescription_enhanced/1001.png
#   inflating: /content/prescription_enhanced/1002.png
#   inflating: /content/prescription_enhanced/1003.png
#   inflating: /content/prescription_enhanced/1004.png
#   inflating: /content/prescription_enhanced/1005.png
#   inflating: /content/prescription_enhanced/1006.png
#   inflating: /content/prescription_enhanced/1007.png
#   inflating: /content/prescription_enhanced/1008.png
#   inflating: /content/prescription_enhanced/1009.png
#   inflating: /content/prescription_enhanced/101.png
#   inflating: /content/prescription_enhanced/1010.png
#   inflating: /content/prescription_enhanced/1011.png
#   inflating: /content/prescription_enhanced/1012.png
#   inflating: /content/prescription_enhanced/1013.png
#   inflating: /content/prescription_enhanced/1014.png
#   inflating: /content/prescription_enhanced/1015.png
#   inflating: /content/prescription_enhanced/1016.png
#   inflating: /content/prescription_enhanced/1017.png
#   inflating: /content/prescription_enhanced/1018.png
#   inflating: /content/prescription_enhanced/1019.png
#   inflating: /content/prescription_enhanced/102.png
#   inflating: /content/prescription_enhanced/1020.png
#   inflating: /content/prescription_enhanced/1021.png
#   inflating: /content/prescription_enhanced/1022.png
#   inflating: /content/prescription_enhanced/1023.png
#   inflating: /content/prescription_enhanced/1024.png
#   inflating: /content/prescription_enhanced/1025.png
#   inflating: /content/prescription_enhanced/1026.png
#   inflating: /content/prescription_enhanced/1027.png
#   inflating: /content/prescription_enhanced/1028.png
#   inflating: /content/prescription_enhanced/1029.png
#   inflating: /content/prescription_enhanced/103.png
#   inflating: /content/prescription_enhanced/1030.png
#   inflating: /content/prescription_enhanced/1031.png
#   inflating: /content/prescription_enhanced/1032.png
#   inflating: /content/prescription_enhanced/1033.png
#   inflating: /content/prescription_enhanced/1034.png
#   inflating: /content/prescription_enhanced/1035.png
#   inflating: /content/prescription_enhanced/1036.png
#   inflating: /content/prescription_enhanced/1037.png
#   inflating: /content/prescription_enhanced/1038.png
#   inflating: /content/prescription_enhanced/1039.png
#   inflating: /content/prescription_enhanced/104.png
#   inflating: /content/prescription_enhanced/1040.png
#   inflating: /content/prescription_enhanced/1041.png
#   inflating: /content/prescription_enhanced/1042.png
#   inflating: /content/prescription_enhanced/1043.png
#   inflating: /content/prescription_enhanced/1044.png
#   inflating: /content/prescription_enhanced/1045.png
#   inflating: /content/prescription_enhanced/1046.png
#   inflating: /content/prescription_enhanced/1047.png
#   inflating: /content/prescription_enhanced/1048.png
#   inflating: /content/prescription_enhanced/1049.png
#   inflating: /content/prescription_enhanced/105.png
#   inflating: /content/prescription_enhanced/1050.png
#   inflating: /content/prescription_enhanced/1051.png
#   inflating: /content/prescription_enhanced/1052.png
#   inflating: /content/prescription_enhanced/1053.png
#   inflating: /content/prescription_enhanced/1054.png
#   inflating: /content/prescription_enhanced/1055.png
#   inflating: /content/prescription_enhanced/1056.png
#   inflating: /content/prescription_enhanced/1057.png
#   inflating: /content/prescription_enhanced/1058.png
#   inflating: /content/prescription_enhanced/1059.png
#   inflating: /content/prescription_enhanced/106.png
#   inflating: /content/prescription_enhanced/1060.png
#   inflating: /content/prescription_enhanced/1061.png
#   inflating: /content/prescription_enhanced/1062.png
#   inflating: /content/prescription_enhanced/1063.png
#   inflating: /content/prescription_enhanced/1064.png
#   inflating: /content/prescription_enhanced/1065.png
#   inflating: /content/prescription_enhanced/1066.png
#   inflating: /content/prescription_enhanced/1067.png
#   inflating: /content/prescription_enhanced/1068.png
#   inflating: /content/prescription_enhanced/1069.png
#   inflating: /content/prescription_enhanced/107.png
#   inflating: /content/prescription_enhanced/1070.png
#   inflating: /content/prescription_enhanced/1071.png
#   inflating: /content/prescription_enhanced/1072.png
#   inflating: /content/prescription_enhanced/1073.png
#   inflating: /content/prescription_enhanced/1074.png
#   inflating: /content/prescription_enhanced/1075.png
#   inflating: /content/prescription_enhanced/1076.png
#   inflating: /content/prescription_enhanced/1077.png
#   inflating: /content/prescription_enhanced/1078.png
#   inflating: /content/prescription_enhanced/1079.png
#   inflating: /content/prescription_enhanced/108.png
#   inflating: /content/prescription_enhanced/1080.png
#   inflating: /content/prescription_enhanced/1081.png
#   inflating: /content/prescription_enhanced/1082.png
#   inflating: /content/prescription_enhanced/1083.png
#   inflating: /content/prescription_enhanced/1084.png
#   inflating: /content/prescription_enhanced/1085.png
#   inflating: /content/prescription_enhanced/1086.png
#   inflating: /content/prescription_enhanced/1087.png
#   inflating: /content/prescription_enhanced/1088.png
#   inflating: /content/prescription_enhanced/1089.png
#   inflating: /content/prescription_enhanced/109.png
#   inflating: /content/prescription_enhanced/1090.png
#   inflating: /content/prescription_enhanced/1091.png
#   inflating: /content/prescription_enhanced/1092.png
#   inflating: /content/prescription_enhanced/1093.png
#   inflating: /content/prescription_enhanced/1094.png
#   inflating: /content/prescription_enhanced/1095.png
#   inflating: /content/prescription_enhanced/1096.png
#   inflating: /content/prescription_enhanced/1097.png
#   inflating: /content/prescription_enhanced/1098.png
#   inflating: /content/prescription_enhanced/1099.png
#   inflating: /content/prescription_enhanced/11.png
#   inflating: /content/prescription_enhanced/110.png
#   inflating: /content/prescription_enhanced/1100.png
#   inflating: /content/prescription_enhanced/1101.png
#   inflating: /content/prescription_enhanced/1102.png
#   inflating: /content/prescription_enhanced/1103.png
#   inflating: /content/prescription_enhanced/1104.png
#   inflating: /content/prescription_enhanced/1105.png
#   inflating: /content/prescription_enhanced/1106.png
#   inflating: /content/prescription_enhanced/1107.png
#   inflating: /content/prescription_enhanced/1108.png
#   inflating: /content/prescription_enhanced/1109.png
#   inflating: /content/prescription_enhanced/111.png
#   inflating: /content/prescription_enhanced/1110.png
#   inflating: /content/prescription_enhanced/1111.png
#   inflating: /content/prescription_enhanced/1112.png
#   inflating: /content/prescription_enhanced/1113.png
#   inflating: /content/prescription_enhanced/1114.png
#   inflating: /content/prescription_enhanced/1115.png
#   inflating: /content/prescription_enhanced/1116.png
#   inflating: /content/prescription_enhanced/1117.png
#   inflating: /content/prescription_enhanced/1118.png
#   inflating: /content/prescription_enhanced/1119.png
#   inflating: /content/prescription_enhanced/112.png
#   inflating: /content/prescription_enhanced/1120.png
#   inflating: /content/prescription_enhanced/1121.png
#   inflating: /content/prescription_enhanced/1122.png
#   inflating: /content/prescription_enhanced/1123.png
#   inflating: /content/prescription_enhanced/1124.png
#   inflating: /content/prescription_enhanced/1125.png
#   inflating: /content/prescription_enhanced/1126.png
#   inflating: /content/prescription_enhanced/1127.png
#   inflating: /content/prescription_enhanced/1128.png
#   inflating: /content/prescription_enhanced/1129.png
#   inflating: /content/prescription_enhanced/113.png
#   inflating: /content/prescription_enhanced/1130.png
#   inflating: /content/prescription_enhanced/1131.png
#   inflating: /content/prescription_enhanced/1132.png
#   inflating: /content/prescription_enhanced/1133.png
#   inflating: /content/prescription_enhanced/1134.png
#   inflating: /content/prescription_enhanced/1135.png
#   inflating: /content/prescription_enhanced/1136.png
#   inflating: /content/prescription_enhanced/1137.png
#   inflating: /content/prescription_enhanced/1138.png
#   inflating: /content/prescription_enhanced/1139.png
#   inflating: /content/prescription_enhanced/114.png
#   inflating: /content/prescription_enhanced/1140.png
#   inflating: /content/prescription_enhanced/1141.png
#   inflating: /content/prescription_enhanced/1142.png
#   inflating: /content/prescription_enhanced/1143.png
#   inflating: /content/prescription_enhanced/1144.png
#   inflating: /content/prescription_enhanced/1145.png
#   inflating: /content/prescription_enhanced/1146.png
#   inflating: /content/prescription_enhanced/1147.png
#   inflating: /content/prescription_enhanced/1148.png
#   inflating: /content/prescription_enhanced/1149.png
#   inflating: /content/prescription_enhanced/115.png
#   inflating: /content/prescription_enhanced/1150.png
#   inflating: /content/prescription_enhanced/1151.png
#   inflating: /content/prescription_enhanced/1152.png
#   inflating: /content/prescription_enhanced/1153.png
#   inflating: /content/prescription_enhanced/1154.png
#   inflating: /content/prescription_enhanced/1155.png
#   inflating: /content/prescription_enhanced/1156.png
#   inflating: /content/prescription_enhanced/1157.png
#   inflating: /content/prescription_enhanced/1158.png
#   inflating: /content/prescription_enhanced/1159.png
#   inflating: /content/prescription_enhanced/116.png
#   inflating: /content/prescription_enhanced/1160.png
#   inflating: /content/prescription_enhanced/1161.png
#   inflating: /content/prescription_enhanced/1162.png
#   inflating: /content/prescription_enhanced/1163.png
#   inflating: /content/prescription_enhanced/1164.png
#   inflating: /content/prescription_enhanced/1165.png
#   inflating: /content/prescription_enhanced/1166.png
#   inflating: /content/prescription_enhanced/1167.png
#   inflating: /content/prescription_enhanced/1168.png
#   inflating: /content/prescription_enhanced/1169.png
#   inflating: /content/prescription_enhanced/117.png
#   inflating: /content/prescription_enhanced/1170.png
#   inflating: /content/prescription_enhanced/1171.png
#   inflating: /content/prescription_enhanced/1172.png
#   inflating: /content/prescription_enhanced/1173.png
#   inflating: /content/prescription_enhanced/1174.png
#   inflating: /content/prescription_enhanced/1175.png
#   inflating: /content/prescription_enhanced/1176.png
#   inflating: /content/prescription_enhanced/1177.png
#   inflating: /content/prescription_enhanced/1178.png
#   inflating: /content/prescription_enhanced/1179.png
#   inflating: /content/prescription_enhanced/118.png
#   inflating: /content/prescription_enhanced/1180.png
#   inflating: /content/prescription_enhanced/1181.png
#   inflating: /content/prescription_enhanced/1182.png
#   inflating: /content/prescription_enhanced/1183.png
#   inflating: /content/prescription_enhanced/1184.png
#   inflating: /content/prescription_enhanced/1185.png
#   inflating: /content/prescription_enhanced/1186.png
#   inflating: /content/prescription_enhanced/1187.png
#   inflating: /content/prescription_enhanced/1188.png
#   inflating: /content/prescription_enhanced/1189.png
#   inflating: /content/prescription_enhanced/119.png
#   inflating: /content/prescription_enhanced/1190.png
#   inflating: /content/prescription_enhanced/1191.png
#   inflating: /content/prescription_enhanced/1192.png
#   inflating: /content/prescription_enhanced/1193.png
#   inflating: /content/prescription_enhanced/1194.png
#   inflating: /content/prescription_enhanced/1195.png
#   inflating: /content/prescription_enhanced/1196.png
#   inflating: /content/prescription_enhanced/1197.png
#   inflating: /content/prescription_enhanced/1198.png
#   inflating: /content/prescription_enhanced/1199.png
#   inflating: /content/prescription_enhanced/12.png
#   inflating: /content/prescription_enhanced/120.png
#   inflating: /content/prescription_enhanced/1200.png
#   inflating: /content/prescription_enhanced/1201.png
#   inflating: /content/prescription_enhanced/1202.png
#   inflating: /content/prescription_enhanced/1203.png
#   inflating: /content/prescription_enhanced/1204.png
#   inflating: /content/prescription_enhanced/1205.png
#   inflating: /content/prescription_enhanced/1206.png
#   inflating: /content/prescription_enhanced/1207.png
#   inflating: /content/prescription_enhanced/1208.png
#   inflating: /content/prescription_enhanced/1209.png
#   inflating: /content/prescription_enhanced/121.png
#   inflating: /content/prescription_enhanced/1210.png
#   inflating: /content/prescription_enhanced/1211.png
#   inflating: /content/prescription_enhanced/1212.png
#   inflating: /content/prescription_enhanced/1213.png
#   inflating: /content/prescription_enhanced/1214.png
#   inflating: /content/prescription_enhanced/1215.png
#   inflating: /content/prescription_enhanced/1216.png
#   inflating: /content/prescription_enhanced/1217.png
#   inflating: /content/prescription_enhanced/1218.png
#   inflating: /content/prescription_enhanced/1219.png
#   inflating: /content/prescription_enhanced/122.png
#   inflating: /content/prescription_enhanced/1220.png
#   inflating: /content/prescription_enhanced/1221.png
#   inflating: /content/prescription_enhanced/1222.png
#   inflating: /content/prescription_enhanced/1223.png
#   inflating: /content/prescription_enhanced/1224.png
#   inflating: /content/prescription_enhanced/1225.png
#   inflating: /content/prescription_enhanced/1226.png
#   inflating: /content/prescription_enhanced/1227.png
#   inflating: /content/prescription_enhanced/1228.png
#   inflating: /content/prescription_enhanced/1229.png
#   inflating: /content/prescription_enhanced/123.png
#   inflating: /content/prescription_enhanced/1230.png
#   inflating: /content/prescription_enhanced/1231.png
#   inflating: /content/prescription_enhanced/1232.png
#   inflating: /content/prescription_enhanced/1233.png
#   inflating: /content/prescription_enhanced/1234.png
#   inflating: /content/prescription_enhanced/1235.png
#   inflating: /content/prescription_enhanced/1236.png
#   inflating: /content/prescription_enhanced/1237.png
#   inflating: /content/prescription_enhanced/1238.png
#   inflating: /content/prescription_enhanced/1239.png
#   inflating: /content/prescription_enhanced/124.png
#   inflating: /content/prescription_enhanced/1240.png
#   inflating: /content/prescription_enhanced/1241.png
#   inflating: /content/prescription_enhanced/1242.png
#   inflating: /content/prescription_enhanced/1243.png
#   inflating: /content/prescription_enhanced/1244.png
#   inflating: /content/prescription_enhanced/1245.png
#   inflating: /content/prescription_enhanced/1246.png
#   inflating: /content/prescription_enhanced/1247.png
#   inflating: /content/prescription_enhanced/1248.png
#   inflating: /content/prescription_enhanced/1249.png
#   inflating: /content/prescription_enhanced/125.png
#   inflating: /content/prescription_enhanced/1250.png
#   inflating: /content/prescription_enhanced/1251.png
#   inflating: /content/prescription_enhanced/1252.png
#   inflating: /content/prescription_enhanced/1253.png
#   inflating: /content/prescription_enhanced/1254.png
#   inflating: /content/prescription_enhanced/1255.png
#   inflating: /content/prescription_enhanced/1256.png
#   inflating: /content/prescription_enhanced/1257.png
#   inflating: /content/prescription_enhanced/1258.png
#   inflating: /content/prescription_enhanced/1259.png
#   inflating: /content/prescription_enhanced/126.png
#   inflating: /content/prescription_enhanced/1260.png
#   inflating: /content/prescription_enhanced/1261.png
#   inflating: /content/prescription_enhanced/1262.png
#   inflating: /content/prescription_enhanced/1263.png
#   inflating: /content/prescription_enhanced/1264.png
#   inflating: /content/prescription_enhanced/1265.png
#   inflating: /content/prescription_enhanced/1266.png
#   inflating: /content/prescription_enhanced/1267.png
#   inflating: /content/prescription_enhanced/1268.png
#   inflating: /content/prescription_enhanced/1269.png
#   inflating: /content/prescription_enhanced/127.png
#   inflating: /content/prescription_enhanced/1270.png
#   inflating: /content/prescription_enhanced/1271.png
#   inflating: /content/prescription_enhanced/1272.png
#   inflating: /content/prescription_enhanced/1273.png
#   inflating: /content/prescription_enhanced/1274.png
#   inflating: /content/prescription_enhanced/1275.png
#   inflating: /content/prescription_enhanced/1276.png
#   inflating: /content/prescription_enhanced/1277.png
#   inflating: /content/prescription_enhanced/1278.png
#   inflating: /content/prescription_enhanced/1279.png
#   inflating: /content/prescription_enhanced/128.png
#   inflating: /content/prescription_enhanced/1280.png
#   inflating: /content/prescription_enhanced/1281.png
#   inflating: /content/prescription_enhanced/1282.png
#   inflating: /content/prescription_enhanced/1283.png
#   inflating: /content/prescription_enhanced/1284.png
#   inflating: /content/prescription_enhanced/1285.png
#   inflating: /content/prescription_enhanced/1286.png
#   inflating: /content/prescription_enhanced/1287.png
#   inflating: /content/prescription_enhanced/1288.png
#   inflating: /content/prescription_enhanced/1289.png
#   inflating: /content/prescription_enhanced/129.png
#   inflating: /content/prescription_enhanced/1290.png
#   inflating: /content/prescription_enhanced/1291.png
#   inflating: /content/prescription_enhanced/1292.png
#   inflating: /content/prescription_enhanced/1293.png
#   inflating: /content/prescription_enhanced/1294.png
#   inflating: /content/prescription_enhanced/1295.png
#   inflating: /content/prescription_enhanced/1296.png
#   inflating: /content/prescription_enhanced/1297.png
#   inflating: /content/prescription_enhanced/1298.png
#   inflating: /content/prescription_enhanced/1299.png
#   inflating: /content/prescription_enhanced/13.png
#   inflating: /content/prescription_enhanced/130.png
#   inflating: /content/prescription_enhanced/1300.png
#   inflating: /content/prescription_enhanced/1301.png
#   inflating: /content/prescription_enhanced/1302.png
#   inflating: /content/prescription_enhanced/1303.png
#   inflating: /content/prescription_enhanced/1304.png
#   inflating: /content/prescription_enhanced/1305.png
#   inflating: /content/prescription_enhanced/1306.png
#   inflating: /content/prescription_enhanced/1307.png
#   inflating: /content/prescription_enhanced/1308.png
#   inflating: /content/prescription_enhanced/1309.png
#   inflating: /content/prescription_enhanced/131.png
#   inflating: /content/prescription_enhanced/1310.png
#   inflating: /content/prescription_enhanced/1311.png
#   inflating: /content/prescription_enhanced/1312.png
#   inflating: /content/prescription_enhanced/1313.png
#   inflating: /content/prescription_enhanced/1314.png
#   inflating: /content/prescription_enhanced/1315.png
#   inflating: /content/prescription_enhanced/1316.png
#   inflating: /content/prescription_enhanced/1317.png
#   inflating: /content/prescription_enhanced/1318.png
#   inflating: /content/prescription_enhanced/1319.png
#   inflating: /content/prescription_enhanced/132.png
#   inflating: /content/prescription_enhanced/1320.png
#   inflating: /content/prescription_enhanced/1321.png
#   inflating: /content/prescription_enhanced/1322.png
#   inflating: /content/prescription_enhanced/1323.png
#   inflating: /content/prescription_enhanced/1324.png
#   inflating: /content/prescription_enhanced/1325.png
#   inflating: /content/prescription_enhanced/1326.png
#   inflating: /content/prescription_enhanced/1327.png
#   inflating: /content/prescription_enhanced/1328.png
#   inflating: /content/prescription_enhanced/1329.png
#   inflating: /content/prescription_enhanced/133.png
#   inflating: /content/prescription_enhanced/1330.png
#   inflating: /content/prescription_enhanced/1331.png
#   inflating: /content/prescription_enhanced/1332.png
#   inflating: /content/prescription_enhanced/1333.png
#   inflating: /content/prescription_enhanced/1334.png
#   inflating: /content/prescription_enhanced/1335.png
#   inflating: /content/prescription_enhanced/1336.png
#   inflating: /content/prescription_enhanced/1337.png
#   inflating: /content/prescription_enhanced/1338.png
#   inflating: /content/prescription_enhanced/1339.png
#   inflating: /content/prescription_enhanced/134.png
#   inflating: /content/prescription_enhanced/1340.png
#   inflating: /content/prescription_enhanced/1341.png
#   inflating: /content/prescription_enhanced/1342.png
#   inflating: /content/prescription_enhanced/1343.png
#   inflating: /content/prescription_enhanced/1344.png
#   inflating: /content/prescription_enhanced/1345.png
#   inflating: /content/prescription_enhanced/1346.png
#   inflating: /content/prescription_enhanced/1347.png
#   inflating: /content/prescription_enhanced/1348.png
#   inflating: /content/prescription_enhanced/1349.png
#   inflating: /content/prescription_enhanced/135.png
#   inflating: /content/prescription_enhanced/1350.png
#   inflating: /content/prescription_enhanced/1351.png
#   inflating: /content/prescription_enhanced/1352.png
#   inflating: /content/prescription_enhanced/1353.png
#   inflating: /content/prescription_enhanced/1354.png
#   inflating: /content/prescription_enhanced/1355.png
#   inflating: /content/prescription_enhanced/1356.png
#   inflating: /content/prescription_enhanced/1357.png
#   inflating: /content/prescription_enhanced/1358.png
#   inflating: /content/prescription_enhanced/1359.png
#   inflating: /content/prescription_enhanced/136.png
#   inflating: /content/prescription_enhanced/1360.png
#   inflating: /content/prescription_enhanced/1361.png
#   inflating: /content/prescription_enhanced/1362.png
#   inflating: /content/prescription_enhanced/1363.png
#   inflating: /content/prescription_enhanced/1364.png
#   inflating: /content/prescription_enhanced/1365.png
#   inflating: /content/prescription_enhanced/1366.png
#   inflating: /content/prescription_enhanced/1367.png
#   inflating: /content/prescription_enhanced/1368.png
#   inflating: /content/prescription_enhanced/1369.png
#   inflating: /content/prescription_enhanced/137.png
#   inflating: /content/prescription_enhanced/1370.png
#   inflating: /content/prescription_enhanced/1371.png
#   inflating: /content/prescription_enhanced/1372.png
#   inflating: /content/prescription_enhanced/1373.png
#   inflating: /content/prescription_enhanced/1374.png
#   inflating: /content/prescription_enhanced/1375.png
#   inflating: /content/prescription_enhanced/1376.png
#   inflating: /content/prescription_enhanced/1377.png
#   inflating: /content/prescription_enhanced/1378.png
#   inflating: /content/prescription_enhanced/1379.png
#   inflating: /content/prescription_enhanced/138.png
#   inflating: /content/prescription_enhanced/1380.png
#   inflating: /content/prescription_enhanced/1381.png
#   inflating: /content/prescription_enhanced/1382.png
#   inflating: /content/prescription_enhanced/1383.png
#   inflating: /content/prescription_enhanced/1384.png
#   inflating: /content/prescription_enhanced/1385.png
#   inflating: /content/prescription_enhanced/1386.png
#   inflating: /content/prescription_enhanced/1387.png
#   inflating: /content/prescription_enhanced/1388.png
#   inflating: /content/prescription_enhanced/1389.png
#   inflating: /content/prescription_enhanced/139.png
#   inflating: /content/prescription_enhanced/1390.png
#   inflating: /content/prescription_enhanced/1391.png
#   inflating: /content/prescription_enhanced/1392.png
#   inflating: /content/prescription_enhanced/1393.png
#   inflating: /content/prescription_enhanced/1394.png
#   inflating: /content/prescription_enhanced/1395.png
#   inflating: /content/prescription_enhanced/1396.png
#   inflating: /content/prescription_enhanced/1397.png
#   inflating: /content/prescription_enhanced/1398.png
#   inflating: /content/prescription_enhanced/1399.png
#   inflating: /content/prescription_enhanced/14.png
#   inflating: /content/prescription_enhanced/140.png
#   inflating: /content/prescription_enhanced/1400.png
#   inflating: /content/prescription_enhanced/1401.png
#   inflating: /content/prescription_enhanced/1402.png
#   inflating: /content/prescription_enhanced/1403.png
#   inflating: /content/prescription_enhanced/1404.png
#   inflating: /content/prescription_enhanced/1405.png
#   inflating: /content/prescription_enhanced/1406.png
#   inflating: /content/prescription_enhanced/1407.png
#   inflating: /content/prescription_enhanced/1408.png
#   inflating: /content/prescription_enhanced/1409.png
#   inflating: /content/prescription_enhanced/141.png
#   inflating: /content/prescription_enhanced/1410.png
#   inflating: /content/prescription_enhanced/1411.png
#   inflating: /content/prescription_enhanced/1412.png
#   inflating: /content/prescription_enhanced/1413.png
#   inflating: /content/prescription_enhanced/1414.png
#   inflating: /content/prescription_enhanced/1415.png
#   inflating: /content/prescription_enhanced/1416.png
#   inflating: /content/prescription_enhanced/1417.png
#   inflating: /content/prescription_enhanced/1418.png
#   inflating: /content/prescription_enhanced/1419.png
#   inflating: /content/prescription_enhanced/142.png
#   inflating: /content/prescription_enhanced/1420.png
#   inflating: /content/prescription_enhanced/1421.png
#   inflating: /content/prescription_enhanced/1422.png
#   inflating: /content/prescription_enhanced/1423.png
#   inflating: /content/prescription_enhanced/1424.png
#   inflating: /content/prescription_enhanced/1425.png
#   inflating: /content/prescription_enhanced/1426.png
#   inflating: /content/prescription_enhanced/1427.png
#   inflating: /content/prescription_enhanced/1428.png
#   inflating: /content/prescription_enhanced/1429.png
#   inflating: /content/prescription_enhanced/143.png
#   inflating: /content/prescription_enhanced/1430.png
#   inflating: /content/prescription_enhanced/1431.png
#   inflating: /content/prescription_enhanced/1432.png
#   inflating: /content/prescription_enhanced/1433.png
#   inflating: /content/prescription_enhanced/1434.png
#   inflating: /content/prescription_enhanced/1435.png
#   inflating: /content/prescription_enhanced/1436.png
#   inflating: /content/prescription_enhanced/1437.png
#   inflating: /content/prescription_enhanced/1438.png
#   inflating: /content/prescription_enhanced/1439.png
#   inflating: /content/prescription_enhanced/144.png
#   inflating: /content/prescription_enhanced/1440.png
#   inflating: /content/prescription_enhanced/1441.png
#   inflating: /content/prescription_enhanced/1442.png
#   inflating: /content/prescription_enhanced/1443.png
#   inflating: /content/prescription_enhanced/1444.png
#   inflating: /content/prescription_enhanced/1445.png
#   inflating: /content/prescription_enhanced/1446.png
#   inflating: /content/prescription_enhanced/1447.png
#   inflating: /content/prescription_enhanced/1448.png
#   inflating: /content/prescription_enhanced/1449.png
#   inflating: /content/prescription_enhanced/145.png
#   inflating: /content/prescription_enhanced/1450.png
#   inflating: /content/prescription_enhanced/1451.png
#   inflating: /content/prescription_enhanced/1452.png
#   inflating: /content/prescription_enhanced/1453.png
#   inflating: /content/prescription_enhanced/1454.png
#   inflating: /content/prescription_enhanced/1455.png
#   inflating: /content/prescription_enhanced/1456.png
#   inflating: /content/prescription_enhanced/1457.png
#   inflating: /content/prescription_enhanced/1458.png
#   inflating: /content/prescription_enhanced/1459.png
#   inflating: /content/prescription_enhanced/146.png
#   inflating: /content/prescription_enhanced/1460.png
#   inflating: /content/prescription_enhanced/1461.png
#   inflating: /content/prescription_enhanced/1462.png
#   inflating: /content/prescription_enhanced/1463.png
#   inflating: /content/prescription_enhanced/1464.png
#   inflating: /content/prescription_enhanced/1465.png
#   inflating: /content/prescription_enhanced/1466.png
#   inflating: /content/prescription_enhanced/1467.png
#   inflating: /content/prescription_enhanced/1468.png
#   inflating: /content/prescription_enhanced/1469.png
#   inflating: /content/prescription_enhanced/147.png
#   inflating: /content/prescription_enhanced/1470.png
#   inflating: /content/prescription_enhanced/1471.png
#   inflating: /content/prescription_enhanced/1472.png
#   inflating: /content/prescription_enhanced/1473.png
#   inflating: /content/prescription_enhanced/1474.png
#   inflating: /content/prescription_enhanced/1475.png
#   inflating: /content/prescription_enhanced/1476.png
#   inflating: /content/prescription_enhanced/1477.png
#   inflating: /content/prescription_enhanced/1478.png
#   inflating: /content/prescription_enhanced/1479.png
#   inflating: /content/prescription_enhanced/148.png
#   inflating: /content/prescription_enhanced/1480.png
#   inflating: /content/prescription_enhanced/1481.png
#   inflating: /content/prescription_enhanced/1482.png
#   inflating: /content/prescription_enhanced/1483.png
#   inflating: /content/prescription_enhanced/1484.png
#   inflating: /content/prescription_enhanced/1485.png
#   inflating: /content/prescription_enhanced/1486.png
#   inflating: /content/prescription_enhanced/1487.png
#   inflating: /content/prescription_enhanced/1488.png
#   inflating: /content/prescription_enhanced/1489.png
#   inflating: /content/prescription_enhanced/149.png
#   inflating: /content/prescription_enhanced/1490.png
#   inflating: /content/prescription_enhanced/1491.png
#   inflating: /content/prescription_enhanced/1492.png
#   inflating: /content/prescription_enhanced/1493.png
#   inflating: /content/prescription_enhanced/1494.png
#   inflating: /content/prescription_enhanced/1495.png
#   inflating: /content/prescription_enhanced/1496.png
#   inflating: /content/prescription_enhanced/1497.png
#   inflating: /content/prescription_enhanced/1498.png
#   inflating: /content/prescription_enhanced/1499.png
#   inflating: /content/prescription_enhanced/15.png
#   inflating: /content/prescription_enhanced/150.png
#   inflating: /content/prescription_enhanced/1500.png
#   inflating: /content/prescription_enhanced/1501.png
#   inflating: /content/prescription_enhanced/1502.png
#   inflating: /content/prescription_enhanced/1503.png
#   inflating: /content/prescription_enhanced/1504.png
#   inflating: /content/prescription_enhanced/1505.png
#   inflating: /content/prescription_enhanced/1506.png
#   inflating: /content/prescription_enhanced/1507.png
#   inflating: /content/prescription_enhanced/1508.png
#   inflating: /content/prescription_enhanced/1509.png
#   inflating: /content/prescription_enhanced/151.png
#   inflating: /content/prescription_enhanced/1510.png
#   inflating: /content/prescription_enhanced/1511.png
#   inflating: /content/prescription_enhanced/1512.png
#   inflating: /content/prescription_enhanced/1513.png
#   inflating: /content/prescription_enhanced/1514.png
#   inflating: /content/prescription_enhanced/1515.png
#   inflating: /content/prescription_enhanced/1516.png
#   inflating: /content/prescription_enhanced/1517.png
#   inflating: /content/prescription_enhanced/1518.png
#   inflating: /content/prescription_enhanced/1519.png
#   inflating: /content/prescription_enhanced/152.png
#   inflating: /content/prescription_enhanced/1520.png
#   inflating: /content/prescription_enhanced/1521.png
#   inflating: /content/prescription_enhanced/1522.png
#   inflating: /content/prescription_enhanced/1523.png
#   inflating: /content/prescription_enhanced/1524.png
#   inflating: /content/prescription_enhanced/1525.png
#   inflating: /content/prescription_enhanced/1526.png
#   inflating: /content/prescription_enhanced/1527.png
#   inflating: /content/prescription_enhanced/1528.png
#   inflating: /content/prescription_enhanced/1529.png
#   inflating: /content/prescription_enhanced/153.png
#   inflating: /content/prescription_enhanced/1530.png
#   inflating: /content/prescription_enhanced/1531.png
#   inflating: /content/prescription_enhanced/1532.png
#   inflating: /content/prescription_enhanced/1533.png
#   inflating: /content/prescription_enhanced/1534.png
#   inflating: /content/prescription_enhanced/1535.png
#   inflating: /content/prescription_enhanced/1536.png
#   inflating: /content/prescription_enhanced/1537.png
#   inflating: /content/prescription_enhanced/1538.png
#   inflating: /content/prescription_enhanced/1539.png
#   inflating: /content/prescription_enhanced/154.png
#   inflating: /content/prescription_enhanced/1540.png
#   inflating: /content/prescription_enhanced/1541.png
#   inflating: /content/prescription_enhanced/1542.png
#   inflating: /content/prescription_enhanced/1543.png
#   inflating: /content/prescription_enhanced/1544.png
#   inflating: /content/prescription_enhanced/1545.png
#   inflating: /content/prescription_enhanced/1546.png
#   inflating: /content/prescription_enhanced/1547.png
#   inflating: /content/prescription_enhanced/1548.png
#   inflating: /content/prescription_enhanced/1549.png
#   inflating: /content/prescription_enhanced/155.png
#   inflating: /content/prescription_enhanced/1550.png
#   inflating: /content/prescription_enhanced/1551.png
#   inflating: /content/prescription_enhanced/1552.png
#   inflating: /content/prescription_enhanced/1553.png
#   inflating: /content/prescription_enhanced/1554.png
#   inflating: /content/prescription_enhanced/1555.png
#   inflating: /content/prescription_enhanced/1556.png
#   inflating: /content/prescription_enhanced/1557.png
#   inflating: /content/prescription_enhanced/1558.png
#   inflating: /content/prescription_enhanced/1559.png
#   inflating: /content/prescription_enhanced/156.png
#   inflating: /content/prescription_enhanced/1560.png
#   inflating: /content/prescription_enhanced/1561.png
#   inflating: /content/prescription_enhanced/1562.png
#   inflating: /content/prescription_enhanced/1563.png
#   inflating: /content/prescription_enhanced/1564.png
#   inflating: /content/prescription_enhanced/1565.png
#   inflating: /content/prescription_enhanced/1566.png
#   inflating: /content/prescription_enhanced/1567.png
#   inflating: /content/prescription_enhanced/1568.png
#   inflating: /content/prescription_enhanced/1569.png
#   inflating: /content/prescription_enhanced/157.png
#   inflating: /content/prescription_enhanced/1570.png
#   inflating: /content/prescription_enhanced/1571.png
#   inflating: /content/prescription_enhanced/1572.png
#   inflating: /content/prescription_enhanced/1573.png
#   inflating: /content/prescription_enhanced/1574.png
#   inflating: /content/prescription_enhanced/1575.png
#   inflating: /content/prescription_enhanced/1576.png
#   inflating: /content/prescription_enhanced/1577.png
#   inflating: /content/prescription_enhanced/1578.png
#   inflating: /content/prescription_enhanced/1579.png
#   inflating: /content/prescription_enhanced/158.png
#   inflating: /content/prescription_enhanced/1580.png
#   inflating: /content/prescription_enhanced/1581.png
#   inflating: /content/prescription_enhanced/1582.png
#   inflating: /content/prescription_enhanced/1583.png
#   inflating: /content/prescription_enhanced/1584.png
#   inflating: /content/prescription_enhanced/1585.png
#   inflating: /content/prescription_enhanced/1586.png
#   inflating: /content/prescription_enhanced/1587.png
#   inflating: /content/prescription_enhanced/1588.png
#   inflating: /content/prescription_enhanced/1589.png
#   inflating: /content/prescription_enhanced/159.png
#   inflating: /content/prescription_enhanced/1590.png
#   inflating: /content/prescription_enhanced/1591.png
#   inflating: /content/prescription_enhanced/1592.png
#   inflating: /content/prescription_enhanced/1593.png
#   inflating: /content/prescription_enhanced/1594.png
#   inflating: /content/prescription_enhanced/1595.png
#   inflating: /content/prescription_enhanced/1596.png
#   inflating: /content/prescription_enhanced/1597.png
#   inflating: /content/prescription_enhanced/1598.png
#   inflating: /content/prescription_enhanced/1599.png
#   inflating: /content/prescription_enhanced/16.png
#   inflating: /content/prescription_enhanced/160.png
#   inflating: /content/prescription_enhanced/1600.png
#   inflating: /content/prescription_enhanced/1601.png
#   inflating: /content/prescription_enhanced/1602.png
#   inflating: /content/prescription_enhanced/1603.png
#   inflating: /content/prescription_enhanced/1604.png
#   inflating: /content/prescription_enhanced/1605.png
#   inflating: /content/prescription_enhanced/1606.png
#   inflating: /content/prescription_enhanced/1607.png
#   inflating: /content/prescription_enhanced/1608.png
#   inflating: /content/prescription_enhanced/1609.png
#   inflating: /content/prescription_enhanced/161.png
#   inflating: /content/prescription_enhanced/1610.png
#   inflating: /content/prescription_enhanced/1611.png
#   inflating: /content/prescription_enhanced/1612.png
#   inflating: /content/prescription_enhanced/1613.png
#   inflating: /content/prescription_enhanced/1614.png
#   inflating: /content/prescription_enhanced/1615.png
#   inflating: /content/prescription_enhanced/1616.png
#   inflating: /content/prescription_enhanced/1617.png
#   inflating: /content/prescription_enhanced/1618.png
#   inflating: /content/prescription_enhanced/1619.png
#   inflating: /content/prescription_enhanced/162.png
#   inflating: /content/prescription_enhanced/1620.png
#   inflating: /content/prescription_enhanced/1621.png
#   inflating: /content/prescription_enhanced/1622.png
#   inflating: /content/prescription_enhanced/1623.png
#   inflating: /content/prescription_enhanced/1624.png
#   inflating: /content/prescription_enhanced/1625.png
#   inflating: /content/prescription_enhanced/1626.png
#   inflating: /content/prescription_enhanced/1627.png
#   inflating: /content/prescription_enhanced/1628.png
#   inflating: /content/prescription_enhanced/1629.png
#   inflating: /content/prescription_enhanced/163.png
#   inflating: /content/prescription_enhanced/1630.png
#   inflating: /content/prescription_enhanced/1631.png
#   inflating: /content/prescription_enhanced/1632.png
#   inflating: /content/prescription_enhanced/1633.png
#   inflating: /content/prescription_enhanced/1634.png
#   inflating: /content/prescription_enhanced/1635.png
#   inflating: /content/prescription_enhanced/1636.png
#   inflating: /content/prescription_enhanced/1637.png
#   inflating: /content/prescription_enhanced/1638.png
#   inflating: /content/prescription_enhanced/1639.png
#   inflating: /content/prescription_enhanced/164.png
#   inflating: /content/prescription_enhanced/1640.png
#   inflating: /content/prescription_enhanced/1641.png
#   inflating: /content/prescription_enhanced/1642.png
#   inflating: /content/prescription_enhanced/1643.png
#   inflating: /content/prescription_enhanced/1644.png
#   inflating: /content/prescription_enhanced/1645.png
#   inflating: /content/prescription_enhanced/1646.png
#   inflating: /content/prescription_enhanced/1647.png
#   inflating: /content/prescription_enhanced/1648.png
#   inflating: /content/prescription_enhanced/1649.png
#   inflating: /content/prescription_enhanced/165.png
#   inflating: /content/prescription_enhanced/1650.png
#   inflating: /content/prescription_enhanced/1651.png
#   inflating: /content/prescription_enhanced/1652.png
#   inflating: /content/prescription_enhanced/1653.png
#   inflating: /content/prescription_enhanced/1654.png
#   inflating: /content/prescription_enhanced/1655.png
#   inflating: /content/prescription_enhanced/1656.png
#   inflating: /content/prescription_enhanced/1657.png
#   inflating: /content/prescription_enhanced/1658.png
#   inflating: /content/prescription_enhanced/1659.png
#   inflating: /content/prescription_enhanced/166.png
#   inflating: /content/prescription_enhanced/1660.png
#   inflating: /content/prescription_enhanced/1661.png
#   inflating: /content/prescription_enhanced/1662.png
#   inflating: /content/prescription_enhanced/1663.png
#   inflating: /content/prescription_enhanced/1664.png
#   inflating: /content/prescription_enhanced/1665.png
#   inflating: /content/prescription_enhanced/1666.png
#   inflating: /content/prescription_enhanced/1667.png
#   inflating: /content/prescription_enhanced/1668.png
#   inflating: /content/prescription_enhanced/1669.png
#   inflating: /content/prescription_enhanced/167.png
#   inflating: /content/prescription_enhanced/1670.png
#   inflating: /content/prescription_enhanced/1671.png
#   inflating: /content/prescription_enhanced/1672.png
#   inflating: /content/prescription_enhanced/1673.png
#   inflating: /content/prescription_enhanced/1674.png
#   inflating: /content/prescription_enhanced/1675.png
#   inflating: /content/prescription_enhanced/1676.png
#   inflating: /content/prescription_enhanced/1677.png
#   inflating: /content/prescription_enhanced/1678.png
#   inflating: /content/prescription_enhanced/1679.png
#   inflating: /content/prescription_enhanced/168.png
#   inflating: /content/prescription_enhanced/1680.png
#   inflating: /content/prescription_enhanced/1681.png
#   inflating: /content/prescription_enhanced/1682.png
#   inflating: /content/prescription_enhanced/1683.png
#   inflating: /content/prescription_enhanced/1684.png
#   inflating: /content/prescription_enhanced/1685.png
#   inflating: /content/prescription_enhanced/1686.png
#   inflating: /content/prescription_enhanced/1687.png
#   inflating: /content/prescription_enhanced/1688.png
#   inflating: /content/prescription_enhanced/1689.png
#   inflating: /content/prescription_enhanced/169.png
#   inflating: /content/prescription_enhanced/1690.png
#   inflating: /content/prescription_enhanced/1691.png
#   inflating: /content/prescription_enhanced/1692.png
#   inflating: /content/prescription_enhanced/1693.png
#   inflating: /content/prescription_enhanced/1694.png
#   inflating: /content/prescription_enhanced/1695.png
#   inflating: /content/prescription_enhanced/1696.png
#   inflating: /content/prescription_enhanced/1697.png
#   inflating: /content/prescription_enhanced/1698.png
#   inflating: /content/prescription_enhanced/1699.png
#   inflating: /content/prescription_enhanced/17.png
#   inflating: /content/prescription_enhanced/170.png
#   inflating: /content/prescription_enhanced/1700.png
#   inflating: /content/prescription_enhanced/1701.png
#   inflating: /content/prescription_enhanced/1702.png
#   inflating: /content/prescription_enhanced/1703.png
#   inflating: /content/prescription_enhanced/1704.png
#   inflating: /content/prescription_enhanced/1705.png
#   inflating: /content/prescription_enhanced/1706.png
#   inflating: /content/prescription_enhanced/1707.png
#   inflating: /content/prescription_enhanced/1708.png
#   inflating: /content/prescription_enhanced/1709.png
#   inflating: /content/prescription_enhanced/171.png
#   inflating: /content/prescription_enhanced/1710.png
#   inflating: /content/prescription_enhanced/1711.png
#   inflating: /content/prescription_enhanced/1712.png
#   inflating: /content/prescription_enhanced/1713.png
#   inflating: /content/prescription_enhanced/1714.png
#   inflating: /content/prescription_enhanced/1715.png
#   inflating: /content/prescription_enhanced/1716.png
#   inflating: /content/prescription_enhanced/1717.png
#   inflating: /content/prescription_enhanced/1718.png
#   inflating: /content/prescription_enhanced/1719.png
#   inflating: /content/prescription_enhanced/172.png
#   inflating: /content/prescription_enhanced/1720.png
#   inflating: /content/prescription_enhanced/1721.png
#   inflating: /content/prescription_enhanced/1722.png
#   inflating: /content/prescription_enhanced/1723.png
#   inflating: /content/prescription_enhanced/1724.png
#   inflating: /content/prescription_enhanced/1725.png
#   inflating: /content/prescription_enhanced/1726.png
#   inflating: /content/prescription_enhanced/1727.png
#   inflating: /content/prescription_enhanced/1728.png
#   inflating: /content/prescription_enhanced/1729.png
#   inflating: /content/prescription_enhanced/173.png
#   inflating: /content/prescription_enhanced/1730.png
#   inflating: /content/prescription_enhanced/1731.png
#   inflating: /content/prescription_enhanced/1732.png
#   inflating: /content/prescription_enhanced/1733.png
#   inflating: /content/prescription_enhanced/1734.png
#   inflating: /content/prescription_enhanced/1735.png
#   inflating: /content/prescription_enhanced/1736.png
#   inflating: /content/prescription_enhanced/1737.png
#   inflating: /content/prescription_enhanced/1738.png
#   inflating: /content/prescription_enhanced/1739.png
#   inflating: /content/prescription_enhanced/174.png
#   inflating: /content/prescription_enhanced/1740.png
#   inflating: /content/prescription_enhanced/1741.png
#   inflating: /content/prescription_enhanced/1742.png
#   inflating: /content/prescription_enhanced/1743.png
#   inflating: /content/prescription_enhanced/1744.png
#   inflating: /content/prescription_enhanced/1745.png
#   inflating: /content/prescription_enhanced/1746.png
#   inflating: /content/prescription_enhanced/1747.png
#   inflating: /content/prescription_enhanced/1748.png
#   inflating: /content/prescription_enhanced/1749.png
#   inflating: /content/prescription_enhanced/175.png
#   inflating: /content/prescription_enhanced/1750.png
#   inflating: /content/prescription_enhanced/1751.png
#   inflating: /content/prescription_enhanced/1752.png
#   inflating: /content/prescription_enhanced/1753.png
#   inflating: /content/prescription_enhanced/1754.png
#   inflating: /content/prescription_enhanced/1755.png
#   inflating: /content/prescription_enhanced/1756.png
#   inflating: /content/prescription_enhanced/1757.png
#   inflating: /content/prescription_enhanced/1758.png
#   inflating: /content/prescription_enhanced/1759.png
#   inflating: /content/prescription_enhanced/176.png
#   inflating: /content/prescription_enhanced/1760.png
#   inflating: /content/prescription_enhanced/1761.png
#   inflating: /content/prescription_enhanced/1762.png
#   inflating: /content/prescription_enhanced/1763.png
#   inflating: /content/prescription_enhanced/1764.png
#   inflating: /content/prescription_enhanced/1765.png
#   inflating: /content/prescription_enhanced/1766.png
#   inflating: /content/prescription_enhanced/1767.png
#   inflating: /content/prescription_enhanced/1768.png
#   inflating: /content/prescription_enhanced/1769.png
#   inflating: /content/prescription_enhanced/177.png
#   inflating: /content/prescription_enhanced/1770.png
#   inflating: /content/prescription_enhanced/1771.png
#   inflating: /content/prescription_enhanced/1772.png
#   inflating: /content/prescription_enhanced/1773.png
#   inflating: /content/prescription_enhanced/1774.png
#   inflating: /content/prescription_enhanced/1775.png
#   inflating: /content/prescription_enhanced/1776.png
#   inflating: /content/prescription_enhanced/1777.png
#   inflating: /content/prescription_enhanced/1778.png
#   inflating: /content/prescription_enhanced/1779.png
#   inflating: /content/prescription_enhanced/178.png
#   inflating: /content/prescription_enhanced/1780.png
#   inflating: /content/prescription_enhanced/1781.png
#   inflating: /content/prescription_enhanced/1782.png
# ...
#   inflating: /content/xray_enhanced/000137 (4).png
#   inflating: /content/xray_enhanced/000137 (8).png
#   inflating: /content/xray_enhanced/000137.png
#   inflating: /content/xray_enhanced/000138 (2).png
#   inflating: /content/xray_enhanced/000138 (6).png
#   inflating: /content/xray_enhanced/000138 (9).png
#   inflating: /content/xray_enhanced/000139 (4).png
#   inflating: /content/xray_enhanced/000139 (5).png
#   inflating: /content/xray_enhanced/000139 (6).png
#   inflating: /content/xray_enhanced/000139 (8).png
#   inflating: /content/xray_enhanced/000139 (9).png
#   inflating: /content/xray_enhanced/000139.png
#   inflating: /content/xray_enhanced/000140.png
#   inflating: /content/xray_enhanced/000141 (2).png
#   inflating: /content/xray_enhanced/000141 (4).png
#   inflating: /content/xray_enhanced/000141.png
#   inflating: /content/xray_enhanced/000142 (5).png
#   inflating: /content/xray_enhanced/000142 (6).png
#   inflating: /content/xray_enhanced/000142.png
#   inflating: /content/xray_enhanced/000143 (5).png
#   inflating: /content/xray_enhanced/000143 (6).png
#   inflating: /content/xray_enhanced/000143.png
#   inflating: /content/xray_enhanced/000144 (2).png
#   inflating: /content/xray_enhanced/000144 (5).png
#   inflating: /content/xray_enhanced/000145 (6).png
#   inflating: /content/xray_enhanced/000145 (9).png
#   inflating: /content/xray_enhanced/000146 (3).png
#   inflating: /content/xray_enhanced/000146 (6).png
#   inflating: /content/xray_enhanced/000147 (2).png
#   inflating: /content/xray_enhanced/000147.png
#   inflating: /content/xray_enhanced/000148 (2).png
#   inflating: /content/xray_enhanced/000148 (3).png
#   inflating: /content/xray_enhanced/000148 (4).png
#   inflating: /content/xray_enhanced/000148 (6).png
#   inflating: /content/xray_enhanced/000148 (8).png
#   inflating: /content/xray_enhanced/000148.png
#   inflating: /content/xray_enhanced/000149 (2).png
#   inflating: /content/xray_enhanced/000149 (4).png
#   inflating: /content/xray_enhanced/000149 (7).png
#   inflating: /content/xray_enhanced/000149.png
#   inflating: /content/xray_enhanced/000150.png
#   inflating: /content/xray_enhanced/000151 (5).png
#   inflating: /content/xray_enhanced/000151 (6).png
#   inflating: /content/xray_enhanced/000151.png
#   inflating: /content/xray_enhanced/000153 (3).png
#   inflating: /content/xray_enhanced/000153 (4).png
#   inflating: /content/xray_enhanced/000153 (5).png
#   inflating: /content/xray_enhanced/000153.png
#   inflating: /content/xray_enhanced/000154 (2).png
#   inflating: /content/xray_enhanced/000154 (3).png
#   inflating: /content/xray_enhanced/000154 (4).png
#   inflating: /content/xray_enhanced/000154.png
#   inflating: /content/xray_enhanced/000155 (3).png
#   inflating: /content/xray_enhanced/000155 (4).png
#   inflating: /content/xray_enhanced/000155.png
#   inflating: /content/xray_enhanced/000156 (2).png
#   inflating: /content/xray_enhanced/000156 (4).png
#   inflating: /content/xray_enhanced/000157 (5).png
#   inflating: /content/xray_enhanced/000157 (6).png
#   inflating: /content/xray_enhanced/000158 (2).png
#   inflating: /content/xray_enhanced/000158 (3).png
#   inflating: /content/xray_enhanced/000158 (4).png
#   inflating: /content/xray_enhanced/000158 (5).png
#   inflating: /content/xray_enhanced/000158 (6).png
#   inflating: /content/xray_enhanced/000158.png
#   inflating: /content/xray_enhanced/000159 (2).png
#   inflating: /content/xray_enhanced/000159 (5).png
#   inflating: /content/xray_enhanced/000159.png
#   inflating: /content/xray_enhanced/000160 (4).png
#   inflating: /content/xray_enhanced/000160 (6).png
#   inflating: /content/xray_enhanced/000160.png
#   inflating: /content/xray_enhanced/000161 (4).png
#   inflating: /content/xray_enhanced/000161 (5).png
#   inflating: /content/xray_enhanced/000162 (2).png
#   inflating: /content/xray_enhanced/000162.png
#   inflating: /content/xray_enhanced/000163 (3).png
#   inflating: /content/xray_enhanced/000163 (4).png
#   inflating: /content/xray_enhanced/000163 (5).png
#   inflating: /content/xray_enhanced/000163 (6).png
#   inflating: /content/xray_enhanced/000163 (7).png
#   inflating: /content/xray_enhanced/000163.png
#   inflating: /content/xray_enhanced/000164 (5).png
#   inflating: /content/xray_enhanced/000165 (6).png
#   inflating: /content/xray_enhanced/000166 (2).png
#   inflating: /content/xray_enhanced/000166 (3).png
#   inflating: /content/xray_enhanced/000166 (4).png
#   inflating: /content/xray_enhanced/000167 (2).png
#   inflating: /content/xray_enhanced/000167 (3).png
#   inflating: /content/xray_enhanced/000167 (8).png
#   inflating: /content/xray_enhanced/000168 (2).png
#   inflating: /content/xray_enhanced/000168 (3).png
#   inflating: /content/xray_enhanced/000169 (6).png
#   inflating: /content/xray_enhanced/000169.png
#   inflating: /content/xray_enhanced/000170 (2).png
#   inflating: /content/xray_enhanced/000170.png
#   inflating: /content/xray_enhanced/000171 (5).png
#   inflating: /content/xray_enhanced/000171.png
#   inflating: /content/xray_enhanced/000172 (2).png
#   inflating: /content/xray_enhanced/000172 (3).png
#   inflating: /content/xray_enhanced/000172 (6).png
#   inflating: /content/xray_enhanced/000172.png
#   inflating: /content/xray_enhanced/000173 (2).png
#   inflating: /content/xray_enhanced/000173 (5).png
#   inflating: /content/xray_enhanced/000173 (7).png
#   inflating: /content/xray_enhanced/000173.png
#   inflating: /content/xray_enhanced/000174 (3).png
#   inflating: /content/xray_enhanced/000174 (4).png
#   inflating: /content/xray_enhanced/000174.png
#   inflating: /content/xray_enhanced/000176 (2).png
#   inflating: /content/xray_enhanced/000177 (3).png
#   inflating: /content/xray_enhanced/000177 (4).png
#   inflating: /content/xray_enhanced/000177.png
#   inflating: /content/xray_enhanced/003828_02_01_174.png
#   inflating: /content/xray_enhanced/004007_01_01_519.png
#   inflating: /content/xray_enhanced/004162_01_01_150.png
#   inflating: /content/xray_enhanced/10 (2) - Copy.png
#   inflating: /content/xray_enhanced/10 (2).png
#   inflating: /content/xray_enhanced/10 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/10 - Copy (2).png
#   inflating: /content/xray_enhanced/10 - Copy (3).png
#   inflating: /content/xray_enhanced/10 - Copy - Copy.png
#   inflating: /content/xray_enhanced/10 - Copy.png
#   inflating: /content/xray_enhanced/10.png
#   inflating: /content/xray_enhanced/11 (2) - Copy.png
#   inflating: /content/xray_enhanced/11 (2).png
#   inflating: /content/xray_enhanced/11 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/11 - Copy (2).png
#   inflating: /content/xray_enhanced/11 - Copy (3).png
#   inflating: /content/xray_enhanced/11 - Copy - Copy.png
#   inflating: /content/xray_enhanced/11 - Copy.png
#   inflating: /content/xray_enhanced/11.png
#   inflating: /content/xray_enhanced/12 (2) - Copy.png
#   inflating: /content/xray_enhanced/12 (2).png
#   inflating: /content/xray_enhanced/12 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/12 - Copy (2).png
#   inflating: /content/xray_enhanced/12 - Copy (3).png
#   inflating: /content/xray_enhanced/12 - Copy - Copy.png
#   inflating: /content/xray_enhanced/12 - Copy.png
#   inflating: /content/xray_enhanced/12.png
#   inflating: /content/xray_enhanced/13 (2) - Copy.png
#   inflating: /content/xray_enhanced/13 (2).png
#   inflating: /content/xray_enhanced/13 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/13 - Copy (2).png
#   inflating: /content/xray_enhanced/13 - Copy (3).png
#   inflating: /content/xray_enhanced/13 - Copy - Copy.png
#   inflating: /content/xray_enhanced/13 - Copy.png
#   inflating: /content/xray_enhanced/13.png
#   inflating: /content/xray_enhanced/16 (2) - Copy.png
#   inflating: /content/xray_enhanced/16 (2).png
#   inflating: /content/xray_enhanced/16 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/16 - Copy (2).png
#   inflating: /content/xray_enhanced/16 - Copy (3).png
#   inflating: /content/xray_enhanced/16 - Copy - Copy.png
#   inflating: /content/xray_enhanced/16 - Copy.png
#   inflating: /content/xray_enhanced/16.png
#   inflating: /content/xray_enhanced/17 (2) - Copy.png
#   inflating: /content/xray_enhanced/17 (2).png
#   inflating: /content/xray_enhanced/17 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/17 - Copy (2).png
#   inflating: /content/xray_enhanced/17 - Copy (3).png
#   inflating: /content/xray_enhanced/17 - Copy - Copy.png
#   inflating: /content/xray_enhanced/17 - Copy.png
#   inflating: /content/xray_enhanced/17.png
#   inflating: /content/xray_enhanced/18 (2) - Copy.png
#   inflating: /content/xray_enhanced/18 (2).png
#   inflating: /content/xray_enhanced/18 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/18 - Copy (2).png
#   inflating: /content/xray_enhanced/18 - Copy (3).png
#   inflating: /content/xray_enhanced/18 - Copy - Copy.png
#   inflating: /content/xray_enhanced/18 - Copy.png
#   inflating: /content/xray_enhanced/18.png
#   inflating: /content/xray_enhanced/19 (2) - Copy.png
#   inflating: /content/xray_enhanced/19 (2).png
#   inflating: /content/xray_enhanced/19 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/19 - Copy (2).png
#   inflating: /content/xray_enhanced/19 - Copy (3).png
#   inflating: /content/xray_enhanced/19 - Copy - Copy.png
#   inflating: /content/xray_enhanced/19 - Copy.png
#   inflating: /content/xray_enhanced/19.png
#   inflating: /content/xray_enhanced/2 (2) - Copy.png
#   inflating: /content/xray_enhanced/2 (2).png
#   inflating: /content/xray_enhanced/2 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/2 - Copy (2).png
#   inflating: /content/xray_enhanced/2 - Copy (3).png
#   inflating: /content/xray_enhanced/2 - Copy - Copy.png
#   inflating: /content/xray_enhanced/2 - Copy.png
#   inflating: /content/xray_enhanced/2.png
#   inflating: /content/xray_enhanced/20 (2) - Copy.png
#   inflating: /content/xray_enhanced/20 (2).png
#   inflating: /content/xray_enhanced/20 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/20 - Copy (2).png
#   inflating: /content/xray_enhanced/20 - Copy (3).png
#   inflating: /content/xray_enhanced/20 - Copy - Copy.png
#   inflating: /content/xray_enhanced/20 - Copy.png
#   inflating: /content/xray_enhanced/20.png
#   inflating: /content/xray_enhanced/21 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/21 - Copy (2).png
#   inflating: /content/xray_enhanced/21 - Copy - Copy.png
#   inflating: /content/xray_enhanced/21 - Copy.png
#   inflating: /content/xray_enhanced/21.png
#   inflating: /content/xray_enhanced/22.png
#   inflating: /content/xray_enhanced/23.png
#   inflating: /content/xray_enhanced/24 - Copy.png
#   inflating: /content/xray_enhanced/24.png
#   inflating: /content/xray_enhanced/25.png
#   inflating: /content/xray_enhanced/3 (2) - Copy.png
#   inflating: /content/xray_enhanced/3 (2).png
#   inflating: /content/xray_enhanced/3 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/3 - Copy (2).png
#   inflating: /content/xray_enhanced/3 - Copy (3).png
#   inflating: /content/xray_enhanced/3 - Copy - Copy.png
#   inflating: /content/xray_enhanced/3 - Copy.png
#   inflating: /content/xray_enhanced/3.png
#   inflating: /content/xray_enhanced/4 (2) - Copy.png
#   inflating: /content/xray_enhanced/4 (2).png
#   inflating: /content/xray_enhanced/4 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/4 - Copy (2).png
#   inflating: /content/xray_enhanced/4 - Copy (3).png
#   inflating: /content/xray_enhanced/4 - Copy - Copy.png
#   inflating: /content/xray_enhanced/4 - Copy.png
#   inflating: /content/xray_enhanced/4.png
#   inflating: /content/xray_enhanced/5 (2) - Copy.png
#   inflating: /content/xray_enhanced/5 (2).png
#   inflating: /content/xray_enhanced/5 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/5 - Copy (2).png
#   inflating: /content/xray_enhanced/5 - Copy (3).png
#   inflating: /content/xray_enhanced/5 - Copy - Copy.png
#   inflating: /content/xray_enhanced/5 - Copy.png
#   inflating: /content/xray_enhanced/5.png
#   inflating: /content/xray_enhanced/6 (2) - Copy.png
#   inflating: /content/xray_enhanced/6 (2).png
#   inflating: /content/xray_enhanced/6 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/6 - Copy (2).png
#   inflating: /content/xray_enhanced/6 - Copy (3).png
#   inflating: /content/xray_enhanced/6 - Copy - Copy.png
#   inflating: /content/xray_enhanced/6 - Copy.png
#   inflating: /content/xray_enhanced/6.png
#   inflating: /content/xray_enhanced/7 (2) - Copy.png
#   inflating: /content/xray_enhanced/7 (2).png
#   inflating: /content/xray_enhanced/7 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/7 - Copy (2).png
#   inflating: /content/xray_enhanced/7 - Copy (3).png
#   inflating: /content/xray_enhanced/7 - Copy - Copy.png
#   inflating: /content/xray_enhanced/7 - Copy.png
#   inflating: /content/xray_enhanced/7.png
#   inflating: /content/xray_enhanced/8 (2) - Copy.png
#   inflating: /content/xray_enhanced/8 (2).png
#   inflating: /content/xray_enhanced/8 - Copy (2) - Copy.png
#   inflating: /content/xray_enhanced/8 - Copy (2).png
#   inflating: /content/xray_enhanced/8 - Copy (3).png
#   inflating: /content/xray_enhanced/8 - Copy - Copy.png
#   inflating: /content/xray_enhanced/8 - Copy.png
#   inflating: /content/xray_enhanced/8.png
#   inflating: /content/xray_enhanced/ad1.png
#   inflating: /content/xray_enhanced/ad10.png
#   inflating: /content/xray_enhanced/ad11.png
#   inflating: /content/xray_enhanced/ad12.png
#   inflating: /content/xray_enhanced/ad13.png
#   inflating: /content/xray_enhanced/ad14.png
#   inflating: /content/xray_enhanced/ad15.png
#   inflating: /content/xray_enhanced/ad16.png
#   inflating: /content/xray_enhanced/ad17.png
#   inflating: /content/xray_enhanced/ad18.png
#   inflating: /content/xray_enhanced/ad19.png
#   inflating: /content/xray_enhanced/ad2.png
#   inflating: /content/xray_enhanced/ad20.png
#   inflating: /content/xray_enhanced/ad21.png
#   inflating: /content/xray_enhanced/ad22.png
#   inflating: /content/xray_enhanced/ad3.png
#   inflating: /content/xray_enhanced/ad4.png
#   inflating: /content/xray_enhanced/ad5.png
#   inflating: /content/xray_enhanced/ad6.png
#   inflating: /content/xray_enhanced/ad7.png
#   inflating: /content/xray_enhanced/ad8.png
#   inflating: /content/xray_enhanced/ad9.png
#   inflating: /content/xray_enhanced/di1.png
#   inflating: /content/xray_enhanced/l1.png
#   inflating: /content/xray_enhanced/l2.png
#   inflating: /content/xray_enhanced/l3.png
#   inflating: /content/xray_enhanced/l4.png
#   inflating: /content/xray_enhanced/l5.png
#   inflating: /content/xray_enhanced/l6.png
#   inflating: /content/xray_enhanced/n6 (2) - Copy.jpg
#   inflating: /content/xray_enhanced/n6 (2).jpg
#   inflating: /content/xray_enhanced/n6 - Copy.jpg
#   inflating: /content/xray_enhanced/n6.jpg
#   inflating: /content/xray_enhanced/n7 (2) - Copy.png
#   inflating: /content/xray_enhanced/n7 (2).png
#   inflating: /content/xray_enhanced/n7 - Copy.png
#   inflating: /content/xray_enhanced/n7.png
#   inflating: /content/xray_enhanced/n8 (2) - Copy.jpg
#   inflating: /content/xray_enhanced/n8 (2).jpg
#   inflating: /content/xray_enhanced/n8 - Copy.jpg
#   inflating: /content/xray_enhanced/n8.jpg
#   inflating: /content/xray_enhanced/n9 (2) - Copy.jpg
#   inflating: /content/xray_enhanced/n9 (2).jpg
#   inflating: /content/xray_enhanced/n9 - Copy.jpg
#   inflating: /content/xray_enhanced/n9.jpg
#   inflating: /content/xray_enhanced/normal - Copy.png
#   inflating: /content/xray_enhanced/normal.png
#   inflating: /content/xray_enhanced/sq1.png
#   inflating: /content/xray_enhanced/sq2.png
#   inflating: /content/xray_enhanced/sq3.png
#   inflating: /content/xray_enhanced/sq4.png
#   inflating: /content/xray_enhanced/sq5.png
#   inflating: /content/xray_enhanced/sq6.png

# %% [markdown]
# ### Step 5 — Clean & Prepare the ICD and Image Index Datasets
#
# We’ll:
# - Keep only relevant columns
# - Clean column names
# - Ensure patient IDs, X-ray IDs, and prescription IDs match a uniform format

# %%
# Clean ICD dataset
df_icd.columns = df_icd.columns.str.strip().str.replace(" ", "_")
df_icd = df_icd.dropna().drop_duplicates()

# Clean image index dataset
df_imgs.columns = df_imgs.columns.str.strip().str.replace(" ", "_")
df_imgs = df_imgs[df_imgs['enhanced_path'].notna()]

# Just to ensure unique patient mapping
# df_imgs = df_imgs.drop_duplicates(subset=['xray_id', 'prescription_id'], keep='first') # Removed this line

print("✅ ICD & Image Data Cleaned")
display(df_icd.head())
display(df_imgs.head())
# Out:
# ✅ ICD & Image Data Cleaned
#   ICDCode                                        Description
# 0    A000     Cholera due to Vibrio cholerae 01, biovar c...
# 1    A001     Cholera due to Vibrio cholerae 01, biovar e...
# 2    A009                               Cholera, unspecified
# 3   A0100                         Typhoid fever, unspecified
# 4   A0101                                 Typhoid meningitis
#                                        original_path  \
# 0  /content/xray_data/XraysData/valid/adenocarcin...
# 1  /content/xray_data/XraysData/valid/adenocarcin...
# 2  /content/xray_data/XraysData/valid/adenocarcin...
# 3  /content/xray_data/XraysData/valid/adenocarcin...
# 4  /content/xray_data/XraysData/valid/adenocarcin...
#
#                                        enhanced_path       psnr      ssim
# 0  /content/enhanced_images/xray_enhanced/000115.png  21.593953  0.746678
# 1  /content/enhanced_images/xray_enhanced/000117 ...  23.827213  0.705685
# 2  /content/enhanced_images/xray_enhanced/000114.png  21.140863  0.734485
# 3  /content/enhanced_images/xray_enhanced/000112 ...  20.423558  0.687321
# 4  /content/enhanced_images/xray_enhanced/000111 ...  22.170544  0.720717

# %% [markdown]
# ### Step 6 — Merge Datasets Logically
#
# We’ll merge:
# 1. **Healthcare data** → Base dataset
# 2. **ICD-10 data** → Mapped by Medical Condition (simple mapping for now)
# 3. **Enhanced image index** → Linked by patient_id / IDs
#
# Later in real integration, semantic ICD mapping and embedding similarity matching can replace this simple join.

# %%
# --- Quick ICD assignment to save time ---
df_health["ICD_Code"] = np.random.choice(df_icd["ICDCode"], size=len(df_health))
df_health = df_health.merge(df_icd, left_on="ICD_Code", right_on="ICDCode", how="left")
df_health.rename(columns={"Description": "ICD_Description"}, inplace=True)
df_health.drop(columns=["ICDCode"], inplace=True)

print("✅ ICD mapping completed (random fast assignment for now)")
display(df_health.sample(1))
# Out:
# ✅ ICD mapping completed (random fast assignment for now)
#       patient_id          Name          Age Gender Blood Type  \
# 43898     P44898  Julie Larson  62-year-old   Male          O
#
#       Medical Condition Date of Admission    Discharge Date  \
# 43898         Arthritis  October 01, 2023  October 25, 2023
#
#                   Doctor        Hospital       Admission Type   Medication  \
# 43898  Kathleen Martinez  Taylor Barrett  Emergency admission  Paracetamol
#
#       Test Results condition_keywords  \
# 43898       Normal          arthritis
#
#                                            summary_input ICD_Code  \
# 43898  Patient Julie Larson, a 62-year-old male with ...  T2044XA
#
#                                          ICD_Description  \
# 43898  War operations involving biological weapons, c...
#
#                                          ICD_Description
# 43898  Corrosion of unspecified degree of nose (septu...

# %%
# --- Fix ICD Mapping (no duplicates) ---
df_health.drop(columns=[col for col in df_health.columns if "ICD_Description" in col], inplace=True, errors='ignore')

# Random ICD code assignment (fast)
df_health["ICD_Code"] = np.random.choice(df_icd["ICDCode"], size=len(df_health))

# Merge only the required ICD description
df_health = df_health.merge(df_icd[["ICDCode", "Description"]], left_on="ICD_Code", right_on="ICDCode", how="left")

# Rename cleanly
df_health.rename(columns={"Description": "ICD_Description"}, inplace=True)
df_health.drop(columns=["ICDCode"], inplace=True)

print("✅ ICD mapping completed (clean, single ICD_Description column).")
display(df_health.head(3))

# Save the dataframe
df_health.to_csv("/content/cleaned_data/healthcare_with_icd.csv", index=False)
print("✅ Healthcare dataset with ICD mapping saved successfully!")
# Out:
# ✅ ICD mapping completed (clean, single ICD_Description column).
#   patient_id           Name          Age  Gender Blood Type Medical Condition  \
# 0      P1000  Bobby Jackson  30-year-old    Male          B            Cancer
# 1      P1001   Leslie Terry  62-year-old    Male         A+           Obesity
# 2      P1002    Danny Smith  76-year-old  Female          A           Obesity
#
#     Date of Admission     Discharge Date            Doctor         Hospital  \
# 0    January 31, 2024  February 02, 2024     Matthew Smith  Sons And Miller
# 1     August 20, 2019    August 26, 2019   Samantha Davies          Kim Inc
# 2  September 22, 2022   October 07, 2022  Tiffany Mitchell         Cook Plc
#
#         Admission Type   Medication  Test Results condition_keywords  \
# 0     Urgent admission  Paracetamol        Normal             cancer
# 1  Emergency admission    Ibuprofen  Inconclusive            obesity
# 2  Emergency admission      Aspirin        Normal            obesity
#
#                                        summary_input ICD_Code  \
# 0  Patient Bobby Jackson, a 30-year-old male with...  S80279A
# 1  Patient Leslie Terry, a 62-year-old male with ...  T17298D
# 2  Patient Danny Smith, a 76-year-old female with...     L234
#
#                                      ICD_Description
# 0  Other superficial bite of unspecified knee, in...
# 1  Other foreign object in pharynx causing other ...
# 2            Allergic contact dermatitis due to dyes
# ✅ Healthcare dataset with ICD mapping saved successfully!

# %%
# =====================================================================
# IMAGE LINKING (for Clinical Note Generation)
# =====================================================================

import pandas as pd
import numpy as np
import os

# ---------------------------------------------------------------------
# 1️⃣ LOAD PROCESSED DATASETS
# ---------------------------------------------------------------------
healthcare_path = "/content/cleaned_data/healthcare_with_icd.csv"      # after ICD merge
image_index_path = "/content/enhanced_image_index.csv"    # from Module 2

df_health = pd.read_csv(healthcare_path)
df_images = pd.read_csv(image_index_path)

print("Healthcare + ICD dataset:", df_health.shape)
print("Enhanced image index:", df_images.shape)

display(df_health.head(2))
display(df_images.head(2))

# ---------------------------------------------------------------------
# 2️⃣ SPLIT IMAGE TYPES
# ---------------------------------------------------------------------
# Infer image type from original_path
df_xray = df_images[df_images["original_path"].str.lower().str.contains("xray", na=False)]
df_pres = df_images[df_images["original_path"].str.lower().str.contains("prescription", na=False)]


print(f"Found {len(df_xray)} X-ray images, {len(df_pres)} prescription images.")

# ---------------------------------------------------------------------
# 3️⃣ SYNTHETICALLY LINK IMAGES TO EACH PATIENT
# ---------------------------------------------------------------------
np.random.seed(42)  # for reproducibility

df_health["xray_image"] = np.random.choice(df_xray["enhanced_path"], size=len(df_health), replace=True)
df_health["prescription_image"] = np.random.choice(df_pres["enhanced_path"], size=len(df_health), replace=True)

print("✅ Linked synthetic image paths to each patient record.")

display(df_health[["patient_id", "Medical Condition", "xray_image", "prescription_image"]].head(5))

# ---------------------------------------------------------------------
# 4️⃣ SAVE THE FINAL COMBINED DATASET
# ---------------------------------------------------------------------
output_path = "/content/cleaned_data/healthcare_with_images.csv"
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df_health.to_csv(output_path, index=False)

print(f"💾 Saved merged dataset → {output_path}")
# Out:
# Healthcare + ICD dataset: (55500, 17)
# Enhanced image index: (5680, 4)
#   patient_id           Name          Age Gender Blood Type Medical Condition  \
# 0      P1000  Bobby Jackson  30-year-old   Male          B            Cancer
# 1      P1001   Leslie Terry  62-year-old   Male         A+           Obesity
#
#   Date of Admission     Discharge Date           Doctor         Hospital  \
# 0  January 31, 2024  February 02, 2024    Matthew Smith  Sons And Miller
# 1   August 20, 2019    August 26, 2019  Samantha Davies          Kim Inc
#
#         Admission Type   Medication  Test Results condition_keywords  \
# 0     Urgent admission  Paracetamol        Normal             cancer
# 1  Emergency admission    Ibuprofen  Inconclusive            obesity
#
#                                        summary_input ICD_Code  \
# 0  Patient Bobby Jackson, a 30-year-old male with...  S80279A
# 1  Patient Leslie Terry, a 62-year-old male with ...  T17298D
#
#                                      ICD_Description
# 0  Other superficial bite of unspecified knee, in...
# 1  Other foreign object in pharynx causing other ...
#                                        original_path  \
# 0  /content/xray_data/XraysData/valid/adenocarcin...
# 1  /content/xray_data/XraysData/valid/adenocarcin...
#
#                                        enhanced_path       psnr      ssim
# 0  /content/enhanced_images/xray_enhanced/000115.png  21.593953  0.746678
# 1  /content/enhanced_images/xray_enhanced/000117 ...  23.827213  0.705685
# Found 1000 X-ray images, 4680 prescription images.
# ✅ Linked synthetic image paths to each patient record.
#   patient_id Medical Condition  \
# 0      P1000            Cancer
# 1      P1001           Obesity
# 2      P1002           Obesity
# 3      P1003          Diabetes
# 4      P1004            Cancer
#
#                                           xray_image  \
# 0  /content/enhanced_images/xray_enhanced/000068 ...
# 1  /content/enhanced_images/xray_enhanced/000077 ...
# 2  /content/enhanced_images/xray_enhanced/000162 ...
# 3      /content/enhanced_images/xray_enhanced/18.png
# 4  /content/enhanced_images/xray_enhanced/000078 ...
#
#                                 prescription_image
# 0  /content/enhanced_images/pres_enhanced/1500.png
# 1  /content/enhanced_images/pres_enhanced/2929.png
# 2   /content/enhanced_images/pres_enhanced/732.png
# 3   /content/enhanced_images/pres_enhanced/277.png
# 4   /content/enhanced_images/pres_enhanced/675.png
# 💾 Saved merged dataset → /content/cleaned_data/healthcare_with_images.csv

# %% [markdown]
# # Summary of Work
#
# In this notebook, we successfully:
# - Loaded and preprocessed the healthcare dataset, including cleaning text, formatting dates and age, and standardizing admission types.
# - Added a unique patient ID to the dataset.
# - Loaded and cleaned the ICD-10 codes dataset and the enhanced image index.
# - Performed a quick, random assignment of ICD codes to patient records.
# - Linked synthetic X-ray and prescription image paths to each patient record.
# - Saved the intermediate and final preprocessed datasets.
#
# This integrated dataset is now ready to be used for generating clinical notes or other text-based AI processing tasks.
